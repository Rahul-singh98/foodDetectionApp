# %%
# !pip install git+https://github.com/Joeclinton1/google-images-download.git
# Out:
# ...
#   Cloning https://github.com/Joeclinton1/google-images-download.git to /tmp/pip-req-build-a1y50lba
#   Running command git clone -q https://github.com/Joeclinton1/google-images-download.git /tmp/pip-req-build-a1y50lba
# ...
#   Created wheel for google-images-download: filename=google_images_download-2.8.0-py2.py3-none-any.whl size=15459 sha256=ea729ed8ac7326c215dc4e4872ceff69b7ea0d2e36d016ad7907b8c7158f1bd8
#   Stored in directory: /tmp/pip-ephem-wheel-cache-gaars_jl/wheels/30/c9/37/0ca2bb35ab9a7fa6289b6a4f5df166d41af49cf48119f4d8bf
# Successfully built google-images-download
# WARNING: You are using pip version 20.1.1; however, version 20.3.3 is available.
# You should consider upgrading via the '/home/rahul/my_project_dir/my_project_env/bin/python3 -m pip install --upgrade pip' command.

# %%
from google_images_download import google_images_download

response = google_images_download.googleimagesdownload()

# %%
#Dal makhani , Pakora , Kofta , Korma , Biryani , Kebab ,Chili peppers , Mustard seeds , Cumin , Fennel , Cardamom , Cinnamon ,Coriander , Turmeric ,Fenugreek , Garam masala , Ghee , samosa , pazham pori , Raita , Achaar ,Burger , french fries , momos , manchurian , pizza , spring rolls , eggroll , chicken roll , Dark chocolate , Ice Cream " , 
# Oat Meal,Oat Bran,Pancakes,waffle,toast,Cheese,milk,yougurt,peanut butter ,Chicken , turkey , beef , lamb ,Salmon , tuna , Beans , sandwitches ,Almonds , peanuts , Cocunuts , walnuts , cashews , Pistachios , Peacans ,Macadamia nuts , Brazil nuts , Hazzlenuts , peanuts , Pinenuts ,BlueBerries , Raspberries , Goji berries  , Strawberries , Bilberries , Acai Berries ,  Cranberries , Grapes  ,Dry Beans , Lentils , Faba Beans 
# Dry peas , chickpeas ,Cowpeas , Bambara Beans , pigeon peas , Lupins , Vetches ,Aloo gobi , Chana masala , Palak paneer , Chicken tikka masala,Crisp papadum ,Shahi paneer , Shahi chaap , Afgani Chaap , Afgani paneer , Bhindi , paratha , malai chaap , chole , chole bhature ,Fish curry , Lamb vindaloo , 
arguments = {"keywords":"Bedhai,Litti Chokha,Jalebi,Omelette,Fafda,Tikki,Paddu,Aloo Dum,Khar,Cheela,Kathi rolls,Vada Pav",
             "limit": 100 , 
                "format":'jpg' , 
                "print_urls":False}

# %%
path = response.download(arguments)
# Out:
# Item no.: 1 --> Item name = Bedhai
# Evaluating...
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Expecting value: line 1 column 1 (char 0)
# Image objects data unpacking failed. Please leave a comment with the above error at https://github.com/hardikvasa/google-images-download/pull/298
# Traceback (most recent call last):
#   File "/home/rahul/my_project_dir/my_project_env/lib/python3.6/site-packages/google_images_download/google_images_download.py", line 237, in download_page
#     return self._image_objects_from_pack(self._extract_data_pack(respData)), self.get_all_tabs(respData)
#   File "/home/rahul/my_project_dir/my_project_env/lib/python3.6/site-packages/google_images_download/google_images_download.py", line 199, in _image_objects_from_pack
#     image_objects = json.loads(data)[31][0][12][2]
#   File "/usr/lib/python3.6/json/__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
# ...

# %%
# !zip -r /home/rahul/Desktop/foodDetectionApp/foodData.zip /home/rahul/Desktop/foodDetectionApp/downloads/
# Out:
#   adding: home/rahul/Desktop/foodDetectionApp/downloads/ (stored 0%)
#   adding: home/rahul/Desktop/foodDetectionApp/downloads/peanut butter / (stored 0%)
#   adding: home/rahul/Desktop/foodDetectionApp/downloads/peanut butter /58.dcd4f799-7353-4e56-ba50-623581cba3bc.jpg (deflated 0%)
#   adding: home/rahul/Desktop/foodDetectionApp/downloads/peanut butter /33.slow-cooker-peanut-butter-chicken.jpg (deflated 1%)
#   adding: home/rahul/Desktop/foodDetectionApp/downloads/peanut butter /32.snapshotimagehandler_1304839084.jpeg (deflated 4%)
#   adding: home/rahul/Desktop/foodDetectionApp/downloads/peanut butter /34.flourless-peanut-butter-cookie-recipe-1-of-1.jpg (deflated 1%)
#   adding: home/rahul/Desktop/foodDetectionApp/downloads/peanut butter /42.peanut-butter-cookies-5.jpg (deflated 0%)
#   adding: home/rahul/Desktop/foodDetectionApp/downloads/peanut butter /54.peanut-butter-cookies-7.jpg (deflated 4%)
# ...
